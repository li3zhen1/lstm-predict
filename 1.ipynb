# %%
import pandas as pd
import matplotlib.pyplot as plt
import mplfinance as mpf

# Creating a DataFrame from the given data
# data = {
#     "Date": ["2006-01-03", "2006-01-04", "2006-01-05", "2006-01-06"],
#     "High": [2.669642925262451, 2.713571310043335, 2.674999952316284, 2.739285707473755],
#     "Low": [2.580357074737549, 2.6607143878936768, 2.6339285373687744, 2.6624999046325684],
#     "Open": [2.5850000381469727, 2.6832141876220703, 2.672499895095825, 2.6875],
#     "Close": [2.669642925262451, 2.677500009536743, 2.656428575515747, 2.7249999046325684],
#     "Volume": [807234400.0, 619603600.0, 449422400.0, 704457600.0],
#     "Adj Close": [2.284266948699951, 2.290989875793457, 2.272961139678955, 2.3316335678100586]
# }

# read data from "archive/Technology Companies/AAPL.csv"
data = pd.read_csv("archive/Technology Companies/DELL.csv")


df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Plotting the data
# plt.figure(figsize=(10, 6))
# plt.plot(df['Date'], df['High'], label='High')
# plt.plot(df['Date'], df['Low'], label='Low')
# plt.plot(df['Date'], df['Open'], label='Open')
# plt.plot(df['Date'], df['Close'], label='Close')
# plt.title('Stock Price Data')
# plt.xlabel('Date')
# plt.ylabel('Price')
# plt.legend()
# plt.grid(True)
# plt.show()

# use mplfinance to plot the data

mpf.plot(df, type='candle', mav=(3, 6, 9), volume=True, show_nontrading=True)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+
